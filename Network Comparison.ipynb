# %%
from train_evaluate.evaluate import evaluate_main

# %%
evaluate_main()
# Out:
# Model_Name:  ssd_300_vgg16_atrous_voc
# Experiment_id:  SAN-49
# params:  sd_300_vgg16_atrous_voc_best_epoch_0031_map_0.9238.param
# pec:  [0.7666666666666667, 0.9555555555555556, 0.8066666666666666, 1.0, 0.889763779527559, 0.8378378378378378, 0.8308823529411765, 0.9841269841269841]
# Model_Name:  ssd_300_vgg16_atrous_voc
# Experiment_id:  SAN-79
# params:  sd_300_vgg16_atrous_voc_best_epoch_0015_map_0.9499.param
# pec:  [0.71875, 0.9885057471264368, 0.7701863354037267, 0.99, 0.937984496124031, 0.9117647058823529, 0.8888888888888888, 0.992]
# Model_Name:  ssd_300_vgg16_atrous_voc
# Experiment_id:  SAN-8
# params:  sd_300_vgg16_atrous_voc_best_epoch_0018_map_0.9138.param
# pec:  [0.7796610169491526, 0.9767441860465116, 0.7735849056603774, 0.9705882352941176, 0.8705035971223022, 0.8611111111111112, 0.9051724137931034, 0.96875]
# Model_Name:  ssd_300_vgg16_atrous_voc
# Experiment_id:  SAN-83
# params:  sd_300_vgg16_atrous_voc_best_epoch_0042_map_0.9409.param
# ...
